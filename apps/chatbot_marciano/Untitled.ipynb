# %%
# imports

import os
from dotenv import load_dotenv
from openai import OpenAI
import anthropic
from IPython.display import Markdown, display, update_display
import random
import google.generativeai
import re
import json
import time

# %%
# Load environment variables in a file called .env
# Print the key prefixes to help with any debugging

load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:8]}")
else:
    print("Google API Key not set")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key exists and begins AIzaSyCl
# DeepSeek API Key exists and begins sk-

# %%
# Connect to OpenAI, Anthropic

openai = OpenAI()

claude = anthropic.Anthropic()

deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com")

google.generativeai.configure()

# --- Modelos ---
gpt_model = "gpt-4.1-mini"
claude_model = "claude-sonnet-4-20250514" #claude-3-5-haiku-latest
deepseek_model = "deepseek-chat"

# %%
# ---------- CONFIGURAÇÃO (edite se quiser) ----------
MIN_VAL = 1
MAX_VAL = 100          # altere para 200 ou 500 para testar escalabilidade
N_ROUNDS = 7
MAX_ATTEMPTS = 5

# %%
# ---------- HELPERS ----------
def extract_integer_from_text(text, min_v=MIN_VAL, max_v=MAX_VAL):
    """Tenta extrair um inteiro válido do texto (mais tolerante)."""
    if not text:
        return None
    # procura números (com sinal)
    nums = re.findall(r'-?\d+', text)
    for n in nums:
        try:
            v = int(n)
            if min_v <= v <= max_v:
                return v
        except:
            continue
    # se não achar, tenta mapear palavras (opcional) - omitido por simplicidade
    return None

def pretty_print_round(player_name, round_i, attempt_i, guess, feedback, secret=None):
    fb = feedback
    s = f"[{player_name}] Rodada {round_i}/{N_ROUNDS} — Tentativa {attempt_i}/{MAX_ATTEMPTS}: chute={guess} -> {fb}"
    if secret is not None:
        s += f" (secreto={secret})"
    print(s)

def summarize_results(results):
    wins = sum(1 for r in results if r['acertou'])
    return {"wins": wins, "rounds": len(results)}

# %%
# ---------- Função para pedir chute ao GPT (stream se disponível) ----------
def ask_gpt_for_guess(previous_attempts, previous_feedbacks, min_v=MIN_VAL, max_v=MAX_VAL):
    """
    Envia ao GPT o estado atual e solicita UM ÚNICO número entre min_v e max_v.
    Retorna (guess:int or None, raw_text:str)
    """
    # system prompt — instrui a saída estrita
    system_prompt = f"""
Você é um jogador humano simulando um jogador real. Seu objetivo: escolher o próximo palpite (APENAS UM NÚMERO inteiro) entre {min_v} e {max_v} para o jogo do marciano.
Você receberá o histórico de tentativas e dicas.
**Responda estritamente** com um único número inteiro dentro do intervalo. Opcionalmente você pode adicionar uma linha curta começando com "RAZÃO:" para justificar — mas a primeira linha deve conter **apenas** o número.
Nada além disso.
"""
    user_msg = f"Histórico:\nTentativas: {previous_attempts}\nDicas: {previous_feedbacks}\nDê o PRÓXIMO palpite (um único número inteiro)."
    # request streaming; se o seu cliente openai não suportar stream=True, remova a opção
    try:
        resp_stream = openai.chat.completions.create(
            model=gpt_model,
            messages=[{"role":"system","content":system_prompt}, {"role":"user","content":user_msg}],
            stream=True
        )
        text = ""
        for chunk in resp_stream:
            delta = chunk.choices[0].delta
            if getattr(delta, "content", None):
                print(delta.content, end="", flush=True)
                text += delta.content
        print()  # nova linha
    except Exception as e:
        # fallback para chamada não-streaming
        resp = openai.chat.completions.create(
            model=gpt_model,
            messages=[{"role":"system","content":system_prompt}, {"role":"user","content":user_msg}]
        )
        text = resp.choices[0].message["content"]
        print(text)
    guess = extract_integer_from_text(text, min_v, max_v)
    return guess, text

# %%
# ---------- Função que executa N_ROUNDS para um "modelo que devolve palpites" (ex: GPT) ----------
def play_model_by_asking_gpt(player_name="ChatGPT"):
    resultados = []
    for r in range(1, N_ROUNDS+1):
        secret = random.randint(MIN_VAL, MAX_VAL)
        tentativas = []
        dicas = []
        acertou = False

        for attempt in range(1, MAX_ATTEMPTS+1):
            guess, raw = ask_gpt_for_guess(tentativas, dicas, MIN_VAL, MAX_VAL)
            # se não extraiu número, usamos fallback (tentar novamente ou chute aleatório)
            if guess is None:
                print(f"[{player_name}] resposta não continha número válido, usando fallback aleatório.")
                guess = random.randint(MIN_VAL, MAX_VAL)
            # registra
            if guess in tentativas:
                # evitar repetir exatamente o mesmo número (é permitido, mas avisamos)
                pass
            tentativas.append(guess)
            # avalia
            if guess == secret:
                feedback = "acertou"
                dicas.append(feedback)
                pretty_print_round(player_name, r, attempt, guess, feedback)
                acertou = True
                break
            elif guess > secret:
                feedback = "mais à esquerda"   # precisa chutar menor
                dicas.append(feedback)
                pretty_print_round(player_name, r, attempt, guess, feedback)
            else:
                feedback = "mais à direita"   # precisa chutar maior
                dicas.append(feedback)
                pretty_print_round(player_name, r, attempt, guess, feedback)

        resultados.append({
            "rodada": r,
            "secreto": secret,
            "tentativas": tentativas,
            "dicas": dicas,
            "acertou": acertou
        })
        # pequeno delay para legibilidade do stream
        time.sleep(0.12)
    return resultados

# %%
# ---------- DEEPSEEK: pedir estratégia (JSON) com base nos resultados do GPT ----------
def request_deepseek_strategy(gpt_results, min_v=MIN_VAL, max_v=MAX_VAL):
    """
    Solicita ao DeepSeek uma estratégia humana e estruturada (JSON).
    Esperamos um JSON com: name, type, description, params, human_steps, pseudocode
    """
    system_prompt = f"""
Você é o DeepSeek. Sua tarefa:
1) Analise os resultados do ChatGPT (dados JSON) e proponha UMA estratégia que possa ser aplicada por um jogador humano para aumentar a taxa de acerto no jogo do marciano.
2) A estratégia deve ser escalável para ranges maiores (por exemplo 1-{min_v} até 1-{max_v}, e se for aplicável, diga como adaptar para 1-200/1-500).
3) **Retorne estritamente apenas um JSON válido** com as chaves:
   - name (string)
   - type ( "binary", "interval", "fixed_sequence", "probabilistic" ou "other" )
   - description (breve)
   - params (objeto de parâmetros se houver)
   - human_steps (lista de passos claros e simples para um humano seguir)
   - pseudocode (string curta com pseudo-código)
Se não puder pensar em algo melhor que busca binária, retorne a busca binária estruturada.
"""
    user_msg = "Resultados do ChatGPT (JSON):\n" + json.dumps(gpt_results, indent=2) + f"\nFaixa: {min_v}-{max_v}\nResponda com JSON."

    # pedimos sem stream para facilitar parser
    try:
        resp = deepseek.chat.completions.create(
            model=deepseek_model,
            messages=[{"role":"system","content":system_prompt}, {"role":"user","content":user_msg}],
            max_tokens=800
        )
        text = resp.choices[0].message.content
    except Exception as e:
        # fallback: se deepseek API não responder por algum motivo, devolvemos estratégia padrão (busca binária)
        print("Erro pedindo estratégia ao DeepSeek:", e)
        text = None

    # tenta extrair JSON do texto retornado
    strategy = None
    if text:
        # extrai o primeiro bloco JSON do texto
        m = re.search(r'(\{.*\})', text, flags=re.DOTALL)
        if m:
            candidate = m.group(1)
            try:
                strategy = json.loads(candidate)
            except Exception as e:
                print("Falha ao parsear JSON retornado pelo DeepSeek — fará fallback para busca binária.")
                strategy = None
        else:
            print("DeepSeek não retornou JSON detectável — fallback para busca binária.")
            strategy = None

    # fallback strategy (binary)
    if strategy is None:
        strategy = {
            "name": "Busca Binária (fallback)",
            "type": "binary",
            "description": "Busca binária clássica: comece pelo meio, reduza intervalo conforme dicas.",
            "params": {},
            "human_steps": [
                "Defina low=min, high=max.",
                "Chute o ponto médio (floor((low+high)/2)).",
                "Recebendo dica 'mais à esquerda' reduza high = guess-1.",
                "Recebendo 'mais à direita' aumente low = guess+1.",
                "Repita até esgotar tentativas."
            ],
            "pseudocode": "while attempts: guess=(low+high)//2; if guess>secret: high=guess-1 elif guess<secret: low=guess+1"
        }

    # Mostra ao usuário a estratégia recebida (raw)
    print("\n--- Estratégia DeepSeek (raw) ---")
    print(json.dumps(strategy, indent=2, ensure_ascii=False))
    print("--- Fim da estratégia ---\n")
    return strategy

# %%
# ---------- Claude: pedir estratégia (JSON) com base nos resultados do GPT ----------
def request_claude_strategy(claude_text, min_v=MIN_VAL, max_v=MAX_VAL):
    """
    Solicita ao Claude uma estratégia humana e estruturada (JSON).
    Esperamos um JSON com: name, type, description, params, human_steps, pseudocode
    """
    system_prompt = f"""
Você é o Claude. Sua tarefa:
1) Analise o relatório feito das jogadas anteriores e proponha UMA estratégia que possa ser aplicada por um jogador humano para aumentar a taxa de acerto no jogo do marciano.
2) A estratégia deve ser escalável para ranges maiores (por exemplo 1-{min_v} até 1-{max_v}, e se for aplicável, diga como adaptar para 1-200/1-500).
3) **Retorne estritamente apenas um JSON válido** com as chaves:
   - name (string)
   - type ( "binary", "interval", "fixed_sequence", "probabilistic" ou "other" )
   - description (breve)
   - params (objeto de parâmetros se houver)
   - human_steps (lista de passos claros e simples para um humano seguir)
   - pseudocode (string curta com pseudo-código)
Se não puder pensar em algo melhor que busca binária, retorne a busca binária estruturada.
"""
    user_msg = "Relatório feito:\n" + json.dumps(claude_text, indent=2) + f"\nFaixa: {min_v}-{max_v}\nResponda com JSON."

    # pedimos sem stream para facilitar parser
    try:
        ans = claude.messages.create(
            model=claude_model,
            system=system_prompt,
            messages=[{"role":"user","content":user_msg}],
            max_tokens=1000
        )
        # dependendo da API, acessar texto pode variar
        text = ans.content[0].text if hasattr(ans, "content") else ans.choices[0].message.content
    except Exception as e:
        # fallback: se deepseek API não responder por algum motivo, devolvemos estratégia padrão (busca binária)
        print("Erro pedindo estratégia ao Claude:", e)
        text = None

    # tenta extrair JSON do texto retornado
    strategy = None
    if text:
        # extrai o primeiro bloco JSON do texto
        m = re.search(r'(\{.*\})', text, flags=re.DOTALL)
        if m:
            candidate = m.group(1)
            try:
                strategy = json.loads(candidate)
            except Exception as e:
                print("Falha ao parsear JSON retornado pelo DeepSeek — fará fallback para busca binária.")
                strategy = None
        else:
            print("DeepSeek não retornou JSON detectável — fallback para busca binária.")
            strategy = None

    # fallback strategy (binary)
    if strategy is None:
        strategy = {
            "name": "Busca Binária (fallback)",
            "type": "binary",
            "description": "Busca binária clássica: comece pelo meio, reduza intervalo conforme dicas.",
            "params": {},
            "human_steps": [
                "Defina low=min, high=max.",
                "Chute o ponto médio (floor((low+high)/2)).",
                "Recebendo dica 'mais à esquerda' reduza high = guess-1.",
                "Recebendo 'mais à direita' aumente low = guess+1.",
                "Repita até esgotar tentativas."
            ],
            "pseudocode": "while attempts: guess=(low+high)//2; if guess>secret: high=guess-1 elif guess<secret: low=guess+1"
        }

    # Mostra ao usuário a estratégia recebida (raw)
    print("\n--- Estratégia DeepSeek (raw) ---")
    print(json.dumps(strategy, indent=2, ensure_ascii=False))
    print("--- Fim da estratégia ---\n")
    return strategy

# %%
# ---------- Executor: converte a estratégia em função que devolve palpites ----------
def make_strategy_fn_from_spec(spec, min_v=MIN_VAL, max_v=MAX_VAL):
    """
    Retorna uma função strategy_fn(tentativas, dicas) -> next_guess
    Implementa 'binary', 'interval', 'fixed_sequence' se possível. Caso desconhecido -> binary fallback.
    """
    t = spec.get("type", "").lower()
    if t == "binary":
        def fn(tentativas, dicas):
            low, high = min_v, max_v
            for g, fb in zip(tentativas, dicas):
                if fb == "mais à esquerda":
                    high = min(high, g-1)
                elif fb == "mais à direita":
                    low = max(low, g+1)
            if low > high:
                # intervalo inválido: retorna um aleatório no min/max
                return random.randint(min_v, max_v)
            return (low + high) // 2
        return fn

    if t == "fixed_sequence":
        seq = spec.get("params", {}).get("sequence", [])
        def fn(tentativas, dicas):
            # escolhe próximo da sequência que ainda não foi tentado
            for s in seq:
                if s not in tentativas and min_v <= s <= max_v:
                    return s
            # fallback
            return random.randint(min_v, max_v)
        return fn

    if t == "interval":
        # interval strategy: split range into k blocks and probe centers
        k = int(spec.get("params", {}).get("blocks", 4)) if spec.get("params") else 4
        def fn(tentativas, dicas):
            # recompute blocks based on feedback
            low, high = min_v, max_v
            for g, fb in zip(tentativas, dicas):
                if fb == "mais à esquerda":
                    high = min(high, g-1)
                elif fb == "mais à direita":
                    low = max(low, g+1)
            if low > high:
                return random.randint(min_v, max_v)
            block_size = max(1, (high - low + 1) // k)
            # choose center of leftmost block not yet probed
            for i in range(k):
                b_low = low + i*block_size
                b_high = min(high, b_low + block_size - 1)
                if b_low > b_high: 
                    continue
                center = (b_low + b_high) // 2
                if center not in tentativas:
                    return center
            return (low + high) // 2
        return fn

    # default fallback binary
    return make_strategy_fn_from_spec({"type":"binary"}, min_v, max_v)

# %%
# ---------- JOGA com a estratégia definida (usado para DeepSeek) ----------
def play_with_strategy_fn(strategy_fn, player_name="DeepSeek"):
    resultados = []
    for r in range(1, N_ROUNDS+1):
        secret = random.randint(MIN_VAL, MAX_VAL)
        tentativas = []
        dicas = []
        acertou = False
        for attempt in range(1, MAX_ATTEMPTS+1):
            guess = strategy_fn(tentativas, dicas)
            # valida range
            if guess is None or not (MIN_VAL <= guess <= MAX_VAL):
                guess = random.randint(MIN_VAL, MAX_VAL)
            tentativas.append(guess)
            # avalia
            if guess == secret:
                feedback = "acertou"
                dicas.append(feedback)
                pretty_print_round(player_name, r, attempt, guess, feedback)
                acertou = True
                break
            elif guess > secret:
                feedback = "mais à esquerda"
                dicas.append(feedback)
                pretty_print_round(player_name, r, attempt, guess, feedback)
            else:
                feedback = "mais à direita"
                dicas.append(feedback)
                pretty_print_round(player_name, r, attempt, guess, feedback)
        resultados.append({
            "rodada": r,
            "secreto": secret,
            "tentativas": tentativas,
            "dicas": dicas,
            "acertou": acertou
        })
        time.sleep(0.06)
    return resultados

# %%
# ---------- CHAMADA AO CLAUDE para comparar (texto final) ----------
def ask_claude_to_compare(gpt_results, deepseek_results, min_v=MIN_VAL, max_v=MAX_VAL):
    system_prompt = f"""
Você é o Claude. Sua tarefa é analisar comparativamente dois agentes que jogaram o 'jogo do marciano' com {MAX_ATTEMPTS} tentativas por rodada.
Receberá os resultados do ChatGPT e do DeepSeek em JSON. Faça:
1) Resumo estatístico: vitórias/rodadas, taxa de acerto (%) e média de tentativas usadas para vitórias.
2) Análise por rodada (destacar rodadas onde um superou o outro).
3) Avalie a estratégia do DeepSeek (se fornecida), se é humana e se escala bem para ranges 1-{min_v} até 1-{max_v} e além (1-200, 1-500).
4) Sugestões práticas para melhorar ambas as IAs (ou a estratégia humana).
Responda em formato de relatório bem estruturado (seções e bullets).
"""
    user_msg = "Resultados ChatGPT:\n" + json.dumps(gpt_results, indent=2, ensure_ascii=False) + "\n\nResultados DeepSeek:\n" + json.dumps(deepseek_results, indent=2, ensure_ascii=False)
    try:
        ans = claude.messages.create(
            model=claude_model,
            system=system_prompt,
            messages=[{"role":"user","content":user_msg}],
            max_tokens=1000
        )
        # dependendo da API, acessar texto pode variar
        text = ans.content[0].text if hasattr(ans, "content") else ans.choices[0].message["content"]
    except Exception as e:
        print("Erro chamando Claude:", e)
        text = "Erro ao chamar Claude: " + str(e)
    print("\n--- Análise do Claude ---\n")
    print(text)
    print("\n--- Fim da análise ---\n")
    return text

# %%
# ---------- PIPELINE COMPLETA ----------
def run_experiment():
    print("\n===== ETAPA 1: ChatGPT joga (real, pedindo palpites ao modelo) =====\n")
    gpt_results = play_model_by_asking_gpt("ChatGPT")

    print("\n===== ETAPA 2: DeepSeek analisa resultados e propõe estratégia =====\n")
    strategy_spec = request_deepseek_strategy(gpt_results, MIN_VAL, MAX_VAL)

    print("\n===== ETAPA 2b: Executor aplica a estratégia proposta (DeepSeek joga realmente) =====\n")
    strategy_fn = make_strategy_fn_from_spec(strategy_spec, MIN_VAL, MAX_VAL)
    deepseek_results = play_with_strategy_fn(strategy_fn, player_name="DeepSeek")

    print("\n===== ETAPA 3: Claude analisa e compara os resultados =====\n")
    claude_text = ask_claude_to_compare(gpt_results, deepseek_results, MIN_VAL, MAX_VAL)

    print("\n===== ETAPA 4: Claude joga com uma nova estratégia =====\n")
    strategy_spec_claude = request_claude_strategy(claude_text, MIN_VAL, MAX_VAL)
    strategy_fn_claude = make_strategy_fn_from_spec(strategy_spec_claude, MIN_VAL, MAX_VAL)
    claude_results = play_with_strategy_fn(strategy_fn_claude, player_name="Claude")

    # resumo final em Python
    print("Resumo final (Python):")
    print("ChatGPT:", summarize_results(gpt_results))
    print("DeepSeek:", summarize_results(deepseek_results))
    return {
        "gpt_results": gpt_results,
        "deepseek_results": deepseek_results,
        "deepseek_strategy": strategy_spec,
        "claude_analysis": claude_text,
        "claude_results:": claude_results
    }

# %%
# ---- Para executar ----
resultado_total = run_experiment()
# Após colar, descomente a linha acima para rodar.
# Out:
# ===== ETAPA 1: ChatGPT joga (real, pedindo palpites ao modelo) =====
#
# 50
# RAZÃO: Primeiro palpite no meio do intervalo para dividir as possibilidades.
# [ChatGPT] Rodada 1/7 — Tentativa 1/5: chute=50 -> mais à esquerda
# 25
# RAZÃO: Como 50 foi alto, escolho o meio do intervalo 1 a 49 para otimizar a busca.
# [ChatGPT] Rodada 1/7 — Tentativa 2/5: chute=25 -> mais à direita
# 37
# RAZÃO: A dica "mais à esquerda" após 50 indica que o número é menor que 50. Depois, "mais à direita" após 25 indica que é maior que 25, então a melhor escolha é um número entre 26 e 49; 37 é o meio desse intervalo.
# [ChatGPT] Rodada 1/7 — Tentativa 3/5: chute=37 -> mais à esquerda
# 31
# RAZÃO: As dicas indicam que o número está entre 25 e 37, mais à esquerda de 37, então 31 é uma boa média.
# [ChatGPT] Rodada 1/7 — Tentativa 4/5: chute=31 -> mais à direita
# 34
# RAZÃO: Entre 31 (mais à direita) e 37 (mais à esquerda), 34 é um palpite razoável no meio do intervalo.
# [ChatGPT] Rodada 1/7 — Tentativa 5/5: chute=34 -> mais à esquerda
# 50
# RAZÃO: Começar pelo meio do intervalo para maximizar a eficiência na busca.
# [ChatGPT] Rodada 2/7 — Tentativa 1/5: chute=50 -> mais à direita
# 75
# RAZÃO: 75 é o meio do intervalo 51-100, seguindo a dica para procurar à direita de 50.
# [ChatGPT] Rodada 2/7 — Tentativa 2/5: chute=75 -> mais à esquerda
# 63
# RAZÃO: O número está entre 50 e 75, então o próximo palpite é a média dos dois (62,5 arredondado para 63).
# [ChatGPT] Rodada 2/7 — Tentativa 3/5: chute=63 -> mais à direita
# 69
# RAZÃO: O número está entre 64 e 74 (após 63 a dica foi 'mais à direita', após 75 'mais à esquerda'). Meio do intervalo é 69.
# [ChatGPT] Rodada 2/7 — Tentativa 4/5: chute=69 -> mais à direita
# 66
# RAZÃO: O único número maior que 63 e 69, mas menor que 75, é 66, seguindo as dicas dadas.
# [ChatGPT] Rodada 2/7 — Tentativa 5/5: chute=66 -> mais à direita
# 50
# RAZÃO: Começar pelo meio do intervalo para dividir o espaço de busca equilibradamente.
# [ChatGPT] Rodada 3/7 — Tentativa 1/5: chute=50 -> mais à direita
# 75
# RAZÃO: "Mais à direita" indica que o número é maior que 50; 75 é o meio entre 51 e 100.
# [ChatGPT] Rodada 3/7 — Tentativa 2/5: chute=75 -> mais à direita
# 88
# RAZÃO: As dicas indicam que o número está acima de 75, então escolho um número razoavelmente no meio do intervalo restante (76-100).
# [ChatGPT] Rodada 3/7 — Tentativa 3/5: chute=88 -> mais à direita
# 94
# RAZÃO: Todas as dicas indicam que o número é maior que 88, então escolho um valor intermediário entre 89 e 100 para otimizar a busca.
# [ChatGPT] Rodada 3/7 — Tentativa 4/5: chute=94 -> mais à direita
# 96
# RAZÃO: Todas as dicas dizem "mais à direita", então o número é maior que 94, testando próximo a 100.
# [ChatGPT] Rodada 3/7 — Tentativa 5/5: chute=96 -> mais à direita
# 50
# RAZÃO: Começando pelo meio do intervalo para aplicar busca binária eficiente.
# [ChatGPT] Rodada 4/7 — Tentativa 1/5: chute=50 -> mais à esquerda
# 25
# RAZÃO: 25 é a média entre 1 e 49, tentando achar o número no meio da faixa "mais à esquerda".
# [ChatGPT] Rodada 4/7 — Tentativa 2/5: chute=25 -> mais à direita
# 37
# RAZÃO: Entre 25 (mais à direita) e 50 (mais à esquerda), a média é 37.5, aproximando para 37 para encontrar o número secreto.
# [ChatGPT] Rodada 4/7 — Tentativa 3/5: chute=37 -> mais à direita
# 44
# RAZÃO: Após 50 ser 'mais à esquerda', o número é <50; 25 ser 'mais à direita' e 37 ser 'mais à direita' indica que o número está entre 38 e 49, então 44 é um bom palpite intermediário.
# [ChatGPT] Rodada 4/7 — Tentativa 4/5: chute=44 -> mais à direita
# 41
# RAZÃO: Após 44 e a indicação "mais à direita", significa que o número é maior que 44. A próxima tentativa lógica entre 44 e 50 (exclusivo) é 41 para ajustar o intervalo.
# [ChatGPT] Rodada 4/7 — Tentativa 5/5: chute=41 -> mais à direita
# 50
# RAZÃO: Começando pelo meio do intervalo para uma busca eficiente.
# [ChatGPT] Rodada 5/7 — Tentativa 1/5: chute=50 -> mais à esquerda
# 25
# RAZÃO: 25 é o meio do intervalo entre 1 e 49, seguindo a dica "mais à esquerda" e estreitando o intervalo.
# [ChatGPT] Rodada 5/7 — Tentativa 2/5: chute=25 -> mais à esquerda
# 12
# RAZÃO: Os palpites foram 50 e 25, ambos 'mais à esquerda', então o número é menor que 25; escolha um valor intermediário entre 1 e 25, como 12.
# [ChatGPT] Rodada 5/7 — Tentativa 3/5: chute=12 -> mais à direita
# 18
# RAZÃO: Entre 12 (última tentativa) e 25, pois foi indicado "mais à direita" na última dica; então 18 é um bom palpite intermediário.
# [ChatGPT] Rodada 5/7 — Tentativa 4/5: chute=18 -> mais à direita
# 15
# RAZÃO: Entre 12 e 18, próximo possível número disponível é 15.
# [ChatGPT] Rodada 5/7 — Tentativa 5/5: chute=15 -> mais à direita
# 50
# RAZÃO: Palpite inicial padrão, divisão do intervalo médio para começar a busca.
# [ChatGPT] Rodada 6/7 — Tentativa 1/5: chute=50 -> mais à direita
# 75
# RAZÃO: O número é maior que 50, então o próximo palpite fica no meio da faixa 51-100.
# [ChatGPT] Rodada 6/7 — Tentativa 2/5: chute=75 -> mais à esquerda
# 62
# RAZÃO: Está entre 51 e 74; 62 é um próximo chute razoável para dividir o intervalo.
# [ChatGPT] Rodada 6/7 — Tentativa 3/5: chute=62 -> mais à esquerda
# 56
# RAZÃO: A sequência indica que o número é maior que 50, menor que 62 e 75 está acima do alvo, então 56 fica no meio do estreito intervalo entre 50 e 62.
# [ChatGPT] Rodada 6/7 — Tentativa 4/5: chute=56 -> mais à direita
# 59
# RAZÃO: O número está entre 56 e 62, então 59 é um palpite razoável para dividir a diferença.
# [ChatGPT] Rodada 6/7 — Tentativa 5/5: chute=59 -> mais à esquerda
# 50
# RAZÃO: Começar com o meio do intervalo para dividir as possibilidades.
# [ChatGPT] Rodada 7/7 — Tentativa 1/5: chute=50 -> mais à direita
# 75
# RAZÃO: O palpite anterior foi 50 com dica "mais à direita", o próximo palpite deve ser maior que 50, utilizando a metade do intervalo restante para aproximar da resposta.
# [ChatGPT] Rodada 7/7 — Tentativa 2/5: chute=75 -> mais à direita
# 88
# RAZÃO: Tentativas anteriores indicam que o número está acima de 75, então escolho próximo ao meio do intervalo restante (76-100).
# [ChatGPT] Rodada 7/7 — Tentativa 3/5: chute=88 -> mais à esquerda
# 82
# RAZÃO: Está entre 75 e 88, mas mais próximo de 88.
# [ChatGPT] Rodada 7/7 — Tentativa 4/5: chute=82 -> mais à direita
# 85
# RAZÃO: Depois de 82 ser "mais à direita", o número está entre 82 e 88; 85 é uma boa tentativa intermediária.
# [ChatGPT] Rodada 7/7 — Tentativa 5/5: chute=85 -> acertou
#
# ===== ETAPA 2: DeepSeek analisa resultados e propõe estratégia =====
#
#
# --- Estratégia DeepSeek (raw) ---
# {
#   "name": "Busca Binária Otimizada com Ajuste de Margem",
#   "type": "binary",
#   "description": "Busca binária clássica com ajuste de margem para evitar oscilações próximas aos limites",
#   "params": {
#     "initial_low": 1,
#     "initial_high": 100,
#     "max_attempts": 7
#   },
#   "human_steps": [
#     "Comece com os limites 1 (baixo) e 100 (alto)",
#     "Calcule o palpite médio: (baixo + alto) ÷ 2 (arredonde para inteiro)",
#     "Se receber 'mais à esquerda', ajuste o limite alto para palpite - 1",
#     "Se receber 'mais à direita', ajuste o limite baixo para palpite + 1",
#     "Repita até acertar ou atingir o máximo de tentativas",
#     "Evite palpite igual ao anterior quando próximo dos limites"
#   ],
#   "pseudocode": "low = 1, high = 100\nfor attempt in range(max_attempts):\n    guess = (low + high) // 2\n    if guess == secret: win\n    elif hint == 'left': high = guess - 1\n    elif hint == 'right': low = guess + 1"
# }
# --- Fim da estratégia ---
#
#
# ===== ETAPA 2b: Executor aplica a estratégia proposta (DeepSeek joga realmente) =====
#
# [DeepSeek] Rodada 1/7 — Tentativa 1/5: chute=50 -> mais à direita
# [DeepSeek] Rodada 1/7 — Tentativa 2/5: chute=75 -> mais à esquerda
# [DeepSeek] Rodada 1/7 — Tentativa 3/5: chute=62 -> mais à esquerda
# [DeepSeek] Rodada 1/7 — Tentativa 4/5: chute=56 -> mais à direita
# [DeepSeek] Rodada 1/7 — Tentativa 5/5: chute=59 -> mais à direita
# [DeepSeek] Rodada 2/7 — Tentativa 1/5: chute=50 -> mais à esquerda
# [DeepSeek] Rodada 2/7 — Tentativa 2/5: chute=25 -> mais à esquerda
# [DeepSeek] Rodada 2/7 — Tentativa 3/5: chute=12 -> mais à esquerda
# [DeepSeek] Rodada 2/7 — Tentativa 4/5: chute=6 -> mais à esquerda
# [DeepSeek] Rodada 2/7 — Tentativa 5/5: chute=3 -> acertou
# [DeepSeek] Rodada 3/7 — Tentativa 1/5: chute=50 -> mais à direita
# [DeepSeek] Rodada 3/7 — Tentativa 2/5: chute=75 -> mais à direita
# [DeepSeek] Rodada 3/7 — Tentativa 3/5: chute=88 -> mais à direita
# [DeepSeek] Rodada 3/7 — Tentativa 4/5: chute=94 -> mais à direita
# [DeepSeek] Rodada 3/7 — Tentativa 5/5: chute=97 -> mais à direita
# [DeepSeek] Rodada 4/7 — Tentativa 1/5: chute=50 -> mais à esquerda
# [DeepSeek] Rodada 4/7 — Tentativa 2/5: chute=25 -> mais à esquerda
# [DeepSeek] Rodada 4/7 — Tentativa 3/5: chute=12 -> mais à direita
# [DeepSeek] Rodada 4/7 — Tentativa 4/5: chute=18 -> mais à direita
# [DeepSeek] Rodada 4/7 — Tentativa 5/5: chute=21 -> mais à esquerda
# [DeepSeek] Rodada 5/7 — Tentativa 1/5: chute=50 -> mais à direita
# [DeepSeek] Rodada 5/7 — Tentativa 2/5: chute=75 -> mais à esquerda
# [DeepSeek] Rodada 5/7 — Tentativa 3/5: chute=62 -> mais à esquerda
# [DeepSeek] Rodada 5/7 — Tentativa 4/5: chute=56 -> mais à esquerda
# [DeepSeek] Rodada 5/7 — Tentativa 5/5: chute=53 -> mais à direita
# [DeepSeek] Rodada 6/7 — Tentativa 1/5: chute=50 -> mais à direita
# [DeepSeek] Rodada 6/7 — Tentativa 2/5: chute=75 -> mais à esquerda
# [DeepSeek] Rodada 6/7 — Tentativa 3/5: chute=62 -> mais à direita
# [DeepSeek] Rodada 6/7 — Tentativa 4/5: chute=68 -> mais à direita
# [DeepSeek] Rodada 6/7 — Tentativa 5/5: chute=71 -> acertou
# [DeepSeek] Rodada 7/7 — Tentativa 1/5: chute=50 -> mais à direita
# [DeepSeek] Rodada 7/7 — Tentativa 2/5: chute=75 -> mais à esquerda
# [DeepSeek] Rodada 7/7 — Tentativa 3/5: chute=62 -> mais à esquerda
# [DeepSeek] Rodada 7/7 — Tentativa 4/5: chute=56 -> mais à esquerda
# [DeepSeek] Rodada 7/7 — Tentativa 5/5: chute=53 -> mais à direita
#
# ===== ETAPA 3: Claude analisa e compara os resultados =====
#
#
# --- Análise do Claude ---
#
# # Relatório Comparativo: ChatGPT vs DeepSeek no Jogo do Marciano
#
# ## 1. Resumo Estatístico
#
# ### Performance Geral
# | Métrica | ChatGPT | DeepSeek |
# |---------|---------|----------|
# | **Vitórias/Rodadas** | 1/7 | 2/7 |
# | **Taxa de Acerto** | 14,3% | 28,6% |
# | **Média de Tentativas (vitórias)** | 5,0 | 5,0 |
# | **Rodadas com acerto** | Rodada 7 | Rodadas 2 e 6 |
#
# ### Observações Iniciais
# - **DeepSeek** demonstrou performance superior com o dobro da taxa de sucesso
# - Ambos utilizaram todas as 5 tentativas disponíveis nas vitórias
# - Nenhum agente conseguiu acertar em menos de 5 tentativas
#
# ## 2. Análise Detalhada por Rodada
#
# ### Rodadas com Diferenças Significativas
#
# **Rodada 2 - Vantagem DeepSeek:**
# - Número secreto: 3 (ChatGPT) vs 3 (DeepSeek)
# - ChatGPT falhou com número 70
# - DeepSeek **acertou** seguindo busca binária perfeita: 50→25→12→6→3
#
# **Rodada 6 - Vantagem DeepSeek:**
# - ChatGPT falhou com número 58
# - DeepSeek **acertou** com número 71, demonstrando convergência eficiente
#
# **Rodada 7 - Vantagem ChatGPT:**
# - ChatGPT **acertou** com número 85
# - DeepSeek falhou com número 54
#
# ### Padrões Estratégicos Observados
#
# **ChatGPT:**
# - Início consistente em 50 (ponto médio)
# - Movimentos por busca binária, mas com algumas inconsistências
# - Dificuldade em ajustes finos nas tentativas finais
#
# **DeepSeek:**
# - Início sempre em 50
# - **Estratégia de busca binária mais consistente**
# - Melhor convergência em números extremos (muito baixos ou altos)
#
# ## 3. Avaliação da Estratégia DeepSeek
#
# ### Características da Estratégia
# - **Busca binária clássica**: Divide consistentemente o espaço de busca pela metade
# - **Início padronizado**: Sempre começa em 50 (ponto médio do range 1-100)
# - **Ajustes sistemáticos**: Movimentos seguem lógica matemática rigorosa
#
# ### Escalabilidade para Diferentes Ranges
#
# **✅ Range 1-100 (atual):**
# - Estratégia adequada e bem executada
# - Máximo teórico: 7 tentativas (log₂(100) ≈ 6,6)
# - Performance real: acerto em 5 tentativas quando bem-sucedido
#
# **✅ Range 1-200:**
# - Escalabilidade excelente
# - Máximo teórico: 8 tentativas (log₂(200) ≈ 7,6)
# - Manteria a mesma eficiência
#
# **✅ Range 1-500 e além:**
# - Estratégia permanece ótima
# - Para 1-500: máximo 9 tentativas (log₂(500) ≈ 8,9)
# - **Limitação**: Com apenas 5 tentativas, ranges muito grandes se tornam impossíveis
#
# ### Humanidade da Estratégia
# - **Altamente sistemática**: Mais algorítmica que humana típica
# - Humanos tendem a fazer "palpites intuitivos" ocasionais
# - **Vantagem**: Consistência superior à intuição humana
#
# ## 4. Sugestões de Melhorias
#
# ### Para ChatGPT
#
# --- Fim da análise ---
#
#
# ===== ETAPA 4: Claude joga com uma nova estratégia =====
#
#
# --- Estratégia DeepSeek (raw) ---
# {
#   "name": "Busca Binária com Micro-Ajustes",
#   "type": "binary",
#   "description": "Busca binária clássica com pequenos ajustes baseados em padrões de distribuição para otimizar as últimas tentativas",
#   "params": {
#     "initial_point": 0.5,
#     "micro_adjustment_factor": 0.1,
#     "apply_adjustment_after_attempt": 3
#   },
#   "human_steps": [
#     "1. Sempre comece no meio do range (50 para 1-100)",
#     "2. Se 'maior': vá para o meio da metade superior",
#     "3. Se 'menor': vá para o meio da metade inferior",
#     "4. A partir da 4ª tentativa, faça micro-ajustes: se o número parece estar em extremos (abaixo de 20 ou acima de 80), ajuste +/-2 da posição binária calculada",
#     "5. Na última tentativa, confie na intuição se houver padrão claro"
#   ],
#   "pseudocode": "inicio = 1, fim = 100\npara cada tentativa:\n  meio = (inicio + fim) / 2\n  se tentativa >= 4 e (meio < 20 ou meio > 80):\n    meio += ajuste_pequeno\n  tentar(meio)\n  atualizar limites baseado na resposta"
# }
# --- Fim da estratégia ---
#
# [Claude] Rodada 1/7 — Tentativa 1/5: chute=50 -> mais à direita
# [Claude] Rodada 1/7 — Tentativa 2/5: chute=75 -> acertou
# [Claude] Rodada 2/7 — Tentativa 1/5: chute=50 -> mais à esquerda
# [Claude] Rodada 2/7 — Tentativa 2/5: chute=25 -> mais à esquerda
# [Claude] Rodada 2/7 — Tentativa 3/5: chute=12 -> mais à esquerda
# [Claude] Rodada 2/7 — Tentativa 4/5: chute=6 -> mais à esquerda
# [Claude] Rodada 2/7 — Tentativa 5/5: chute=3 -> acertou
# [Claude] Rodada 3/7 — Tentativa 1/5: chute=50 -> mais à esquerda
# [Claude] Rodada 3/7 — Tentativa 2/5: chute=25 -> mais à direita
# [Claude] Rodada 3/7 — Tentativa 3/5: chute=37 -> mais à esquerda
# [Claude] Rodada 3/7 — Tentativa 4/5: chute=31 -> acertou
# [Claude] Rodada 4/7 — Tentativa 1/5: chute=50 -> mais à direita
# [Claude] Rodada 4/7 — Tentativa 2/5: chute=75 -> mais à direita
# [Claude] Rodada 4/7 — Tentativa 3/5: chute=88 -> mais à esquerda
# [Claude] Rodada 4/7 — Tentativa 4/5: chute=81 -> mais à esquerda
# [Claude] Rodada 4/7 — Tentativa 5/5: chute=78 -> mais à esquerda
# [Claude] Rodada 5/7 — Tentativa 1/5: chute=50 -> mais à direita
# [Claude] Rodada 5/7 — Tentativa 2/5: chute=75 -> mais à esquerda
# [Claude] Rodada 5/7 — Tentativa 3/5: chute=62 -> mais à direita
# [Claude] Rodada 5/7 — Tentativa 4/5: chute=68 -> mais à esquerda
# [Claude] Rodada 5/7 — Tentativa 5/5: chute=65 -> acertou
# [Claude] Rodada 6/7 — Tentativa 1/5: chute=50 -> mais à direita
# [Claude] Rodada 6/7 — Tentativa 2/5: chute=75 -> mais à esquerda
# [Claude] Rodada 6/7 — Tentativa 3/5: chute=62 -> mais à direita
# [Claude] Rodada 6/7 — Tentativa 4/5: chute=68 -> mais à direita
# [Claude] Rodada 6/7 — Tentativa 5/5: chute=71 -> mais à direita
# [Claude] Rodada 7/7 — Tentativa 1/5: chute=50 -> mais à direita
# [Claude] Rodada 7/7 — Tentativa 2/5: chute=75 -> mais à direita
# [Claude] Rodada 7/7 — Tentativa 3/5: chute=88 -> mais à esquerda
# [Claude] Rodada 7/7 — Tentativa 4/5: chute=81 -> mais à direita
# [Claude] Rodada 7/7 — Tentativa 5/5: chute=84 -> mais à esquerda
# Resumo final (Python):
# ChatGPT: {'wins': 1, 'rounds': 7}
# DeepSeek: {'wins': 2, 'rounds': 7}
